# %% [markdown]
# # 1. Setup Mario

# %%
# !pip install gym_super_mario_bros==7.3.0 nes_py
# Out:
# Collecting gym_super_mario_bros==7.3.0
#   Using cached https://files.pythonhosted.org/packages/a0/b8/07460212c2568f78b02995834e7bdc25349e586473919e2983e01b984abf/gym_super_mario_bros-7.3.0-py2.py3-none-any.whl
# Collecting nes_py
#   Using cached https://files.pythonhosted.org/packages/04/6b/51c9efe4fc67a9311b1125a19ec7a6176c8f0b8334e418d7f5bc53aeec56/nes_py-8.2.1.tar.gz
# Collecting gym>=0.17.2 (from nes_py)
# Collecting numpy>=1.18.5 (from nes_py)
#   Using cached https://files.pythonhosted.org/packages/69/65/0d47953afa0ad569d12de5f65d964321c208492064c38fe3b0b9744f8d44/numpy-1.24.4-cp38-cp38-win_amd64.whl
# Collecting pyglet<=1.5.21,>=1.4.0 (from nes_py)
#   Using cached https://files.pythonhosted.org/packages/0b/b7/7736d7638d91b354700dc9bae447728c514c4bc6ecb4c0f7e0cd9a390f20/pyglet-1.5.21-py3-none-any.whl
# Collecting tqdm>=4.48.2 (from nes_py)
#   Using cached https://files.pythonhosted.org/packages/2a/14/e75e52d521442e2fcc9f1df3c5e456aead034203d4797867980de558ab34/tqdm-4.66.2-py3-none-any.whl
# Collecting cloudpickle>=1.2.0 (from gym>=0.17.2->nes_py)
#   Using cached https://files.pythonhosted.org/packages/96/43/dae06432d0c4b1dc9e9149ad37b4ca8384cf6eb7700cd9215b177b914f0a/cloudpickle-3.0.0-py3-none-any.whl
# Collecting gym-notices>=0.0.4 (from gym>=0.17.2->nes_py)
#   Using cached https://files.pythonhosted.org/packages/25/26/d786c6bec30fe6110fd3d22c9a273a2a0e56c0b73b93e25ea1af5a53243b/gym_notices-0.0.8-py3-none-any.whl
# Requirement already satisfied: importlib-metadata>=4.8.0; python_version < "3.10" in d:\github\retro-game\env\lib\site-packages (from gym>=0.17.2->nes_py) (7.0.1)
# Requirement already satisfied: colorama; platform_system == "Windows" in d:\github\retro-game\env\lib\site-packages (from tqdm>=4.48.2->nes_py) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in d:\github\retro-game\env\lib\site-packages (from importlib-metadata>=4.8.0; python_version < "3.10"->gym>=0.17.2->nes_py) (3.17.0)
# Installing collected packages: cloudpickle, gym-notices, numpy, gym, pyglet, tqdm, nes-py, gym-super-mario-bros
#   Running setup.py install for nes-py: started
#     Running setup.py install for nes-py: finished with status 'done'
# Successfully installed cloudpickle-3.0.0 gym-0.26.2 gym-notices-0.0.8 gym-super-mario-bros-7.3.0 nes-py-8.2.1 numpy-1.24.4 pyglet-1.5.21 tqdm-4.66.2
# WARNING: You are using pip version 19.2.3, however version 24.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Import the game
import gym_super_mario_bros
# Import the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# Import the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
# Setup game
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# Out:
# d:\Github\Retro-game\env38\lib\site-packages\gym\envs\registration.py:564: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# d:\Github\Retro-game\env38\lib\site-packages\gym\utils\passive_env_checker.py:97: UserWarning: WARN: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   logger.warn(

# %%
# Create a flag - restart or not
done = True
# Loop through each frame in the game
for step in range(100000): 
    # Start the game to begin with 
    if done: 
        # Start the gamee
        env.reset()
    # Do random actions
    state, reward, done, info = env.step(env.action_space.sample())

    # Show the game on the screen
    env.render()
# Close the game
env.close()
# Out:
# d:\Github\Retro-game\env38\lib\site-packages\gym\utils\passive_env_checker.py:297: UserWarning: WARN: No render modes was declared in the environment (env.metadata['render_modes'] is None or not defined), you may have trouble when calling `.render()`
#   logger.warn(
# d:\Github\Retro-game\env38\lib\site-packages\gym\utils\passive_env_checker.py:305: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps
#   logger.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 13
#      10     state, reward, done, info = env.step(env.action_space.sample())
#      12     # Show the game on the screen
# ---> 13     env.render()
#      14 # Close the game
#      15 env.close()
#
# File d:\Github\Retro-game\env38\lib\site-packages\gym\core.py:343, in Wrapper.render(self, **kwargs)
#     341 def render(self, **kwargs):
#     342     """Renders the environment with kwargs."""
# --> 343     return self.env.render(**kwargs)
#
# File d:\Github\Retro-game\env38\lib\site-packages\gym\core.py:343, in Wrapper.render(self, **kwargs)
#     341 def render(self, **kwargs):
#     342     """Renders the environment with kwargs."""
# --> 343     return self.env.render(**kwargs)
#
# File d:\Github\Retro-game\env38\lib\site-packages\gym\wrappers\order_enforcing.py:51, in OrderEnforcing.render(self, **kwargs)
#      46 if not self._disable_render_order_enforcing and not self._has_reset:
#      47     raise ResetNeeded(
#      48         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      49         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50     )
# ---> 51 return self.env.render(**kwargs)
#
# File d:\Github\Retro-game\env38\lib\site-packages\gym\wrappers\env_checker.py:57, in PassiveEnvChecker.render(self, **kwargs)
#      55     return passive_env_render_check(self.env, **kwargs)
#      56 else:
# ---> 57     return self.env.render(**kwargs)
#
# File d:\Github\Retro-game\env38\lib\site-packages\nes_py\nes_env.py:386, in NESEnv.render(self, mode)
#     380         self.viewer = ImageViewer(
#     381             caption=caption,
#     382             height=SCREEN_HEIGHT,
#     383             width=SCREEN_WIDTH,
#     384         )
#     385     # show the screen on the image viewer
# --> 386     self.viewer.show(self.screen)
#     387 elif mode == 'rgb_array':
#     388     return self.screen
#
# File d:\Github\Retro-game\env38\lib\site-packages\nes_py\_image_viewer.py:148, in ImageViewer.show(self, frame)
#     140 image = self.pyglet.image.ImageData(
#     141     frame.shape[1],
#     142     frame.shape[0],
#    (...)
#     145     pitch=frame.shape[1]*-3
#     146 )
#     147 # send the image to the window
# --> 148 image.blit(0, 0, width=self._window.width, height=self._window.height)
#     149 self._window.flip()
#
# File d:\Github\Retro-game\env38\lib\site-packages\pyglet\image\__init__.py:904, in ImageData.blit(self, x, y, z, width, height)
#     903 def blit(self, x, y, z=0, width=None, height=None):
# --> 904     self.get_texture().blit(x, y, z, width, height)
#
# File d:\Github\Retro-game\env38\lib\site-packages\pyglet\image\__init__.py:835, in ImageData.get_texture(self, rectangle, force_rectangle)
#     832 def get_texture(self, rectangle=False, force_rectangle=False):
#     833     if (not self._current_texture or
#     834             (not self._current_texture._is_rectangle and force_rectangle)):
# --> 835         self._current_texture = self.create_texture(Texture, rectangle, force_rectangle)
#     836     return self._current_texture
#
# File d:\Github\Retro-game\env38\lib\site-packages\pyglet\image\__init__.py:821, in ImageData.create_texture(self, cls, rectangle, force_rectangle)
#     798 """Create a texture containing this image.
#     799
#     800 If the image's dimensions are not powers of 2, a TextureRegion of
#    (...)
#     818 :rtype: cls or cls.region_class
#     819 """
#     820 internalformat = self._get_internalformat(self.format)
# --> 821 texture = cls.create(self.width, self.height, internalformat,
#     822                      rectangle, force_rectangle)
#     823 if self.anchor_x or self.anchor_y:
#     824     texture.anchor_x = self.anchor_x
#
# File d:\Github\Retro-game\env38\lib\site-packages\pyglet\image\__init__.py:1471, in Texture.create(cls, width, height, internalformat, rectangle, force_rectangle, min_filter, mag_filter)
#    1468 glTexParameteri(target, GL_TEXTURE_MAG_FILTER, mag_filter)
#    1470 blank = (GLubyte * (texture_width * texture_height * 4))()
# -> 1471 glTexImage2D(target, 0,
#    1472              internalformat,
#    1473              texture_width, texture_height,
#    1474              0,
#    1475              GL_RGBA, GL_UNSIGNED_BYTE,
#    1476              blank)
#    1478 texture = cls(texture_width, texture_height, target, id.value)
#    1479 texture.min_filter = min_filter
#
# File d:\Github\Retro-game\env38\lib\site-packages\pyglet\gl\lib.py:87, in errcheck(result, func, arguments)
#      83 class GLException(Exception):
#      84     pass
# ---> 87 def errcheck(result, func, arguments):
#      88     if _debug_gl_trace:
#      89         try:
#
# KeyboardInterrupt:

# %% [markdown]
# # 2. Preprocess Environment

# %%
# Install pytorch
# !pip install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio===0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /whl/cu113/torch_stable.html
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /whl/cu113/torch_stable.html
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /whl/cu113/torch_stable.html
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /whl/cu113/torch_stable.html
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /whl/cu113/torch_stable.html
# ERROR: Could not find a version that satisfies the requirement torch==1.10.1+cu113 (from versions: 1.7.1, 1.8.0, 1.8.1, 1.9.0, 1.9.1, 1.10.0, 1.10.1, 1.10.2, 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1)
# ERROR: No matching distribution found for torch==1.10.1+cu113

# %%
# Install stable baselines for RL stuff
# !pip install stable-baselines3[extra]
# Out:
# Collecting stable-baselines3[extra]
#   Using cached stable_baselines3-2.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3[extra])
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.20 in d:\github\retro-game\env38\lib\site-packages (from stable-baselines3[extra]) (1.24.4)
# Collecting torch>=1.13 (from stable-baselines3[extra])
#   Using cached torch-2.2.1-cp38-cp38-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: cloudpickle in d:\github\retro-game\env38\lib\site-packages (from stable-baselines3[extra]) (3.0.0)
# Collecting pandas (from stable-baselines3[extra])
#   Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# Collecting matplotlib (from stable-baselines3[extra])
#   Using cached matplotlib-3.7.5-cp38-cp38-win_amd64.whl.metadata (5.8 kB)
# Collecting opencv-python (from stable-baselines3[extra])
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pygame in d:\github\retro-game\env38\lib\site-packages (from stable-baselines3[extra]) (2.5.2)
# Collecting tensorboard>=2.9.1 (from stable-baselines3[extra])
#   Downloading tensorboard-2.14.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: psutil in d:\github\retro-game\env38\lib\site-packages (from stable-baselines3[extra]) (5.9.8)
# Requirement already satisfied: tqdm in d:\github\retro-game\env38\lib\site-packages (from stable-baselines3[extra]) (4.66.2)
# Collecting rich (from stable-baselines3[extra])
#   Using cached rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting shimmy~=1.3.0 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra])
#   Using cached Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting pillow (from stable-baselines3[extra])
#   Using cached pillow-10.2.0-cp38-cp38-win_amd64.whl.metadata (9.9 kB)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting click (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting requests (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting importlib-resources (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Using cached importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ---------------------------------------- 0.0/434.7 kB ? eta -:--:--
#      ------- ------------------------------- 81.9/434.7 kB 2.3 MB/s eta 0:00:01
#      ------------------- ------------------ 225.3/434.7 kB 2.8 MB/s eta 0:00:01
#      -------------------------------------- 434.7/434.7 kB 3.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: typing-extensions>=4.3.0 in d:\github\retro-game\env38\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.9.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra])
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: importlib-metadata>=4.8.0 in d:\github\retro-game\env38\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (7.0.1)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra])
#   Using cached ale_py-0.8.1-cp38-cp38-win_amd64.whl.metadata (8.3 kB)
# Collecting absl-py>=0.4 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading grpcio-1.62.0-cp38-cp38-win_amd64.whl.metadata (4.2 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading google_auth-2.28.1-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading Markdown-3.5.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf>=3.19.6 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading protobuf-4.25.3-cp38-cp38-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in d:\github\retro-game\env38\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (41.2.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting wheel>=0.26 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Using cached wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting filelock (from torch>=1.13->stable-baselines3[extra])
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting sympy (from torch>=1.13->stable-baselines3[extra])
#   Using cached sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.13->stable-baselines3[extra])
#   Using cached networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting jinja2 (from torch>=1.13->stable-baselines3[extra])
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting fsspec (from torch>=1.13->stable-baselines3[extra])
#   Using cached fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->stable-baselines3[extra])
#   Using cached contourpy-1.1.1-cp38-cp38-win_amd64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib->stable-baselines3[extra])
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->stable-baselines3[extra])
#   Using cached fonttools-4.49.0-cp38-cp38-win_amd64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib->stable-baselines3[extra])
#   Using cached kiwisolver-1.4.5-cp38-cp38-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in d:\github\retro-game\env38\lib\site-packages (from matplotlib->stable-baselines3[extra]) (23.2)
# Collecting pyparsing>=2.3.1 (from matplotlib->stable-baselines3[extra])
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\github\retro-game\env38\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Collecting pytz>=2020.1 (from pandas->stable-baselines3[extra])
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas->stable-baselines3[extra])
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->stable-baselines3[extra])
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\github\retro-game\env38\lib\site-packages (from rich->stable-baselines3[extra]) (2.17.2)
# Requirement already satisfied: colorama in d:\github\retro-game\env38\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: zipp>=0.5 in d:\github\retro-game\env38\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (3.17.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra])
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in d:\github\retro-game\env38\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3[extra]) (1.16.0)
# Collecting charset-normalizer<4,>=2 (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Using cached charset_normalizer-3.3.2-cp38-cp38-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra])
#   Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl.metadata (3.1 kB)
# Collecting mpmath>=0.19 (from sympy->torch>=1.13->stable-baselines3[extra])
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Using cached Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Downloading tensorboard-2.14.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    - -------------------------------------- 0.2/5.5 MB 3.9 MB/s eta 0:00:02
#    --- ------------------------------------ 0.5/5.5 MB 4.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.6/5.5 MB 3.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.8/5.5 MB 3.9 MB/s eta 0:00:02
#    ------- -------------------------------- 1.0/5.5 MB 4.0 MB/s eta 0:00:02
#    --------- ------------------------------ 1.3/5.5 MB 4.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.5/5.5 MB 4.3 MB/s eta 0:00:01
#    ------------ --------------------------- 1.7/5.5 MB 4.3 MB/s eta 0:00:01
#    -------------- ------------------------- 2.0/5.5 MB 4.5 MB/s eta 0:00:01
#    --------------- ------------------------ 2.1/5.5 MB 4.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.2/5.5 MB 4.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.4/5.5 MB 4.1 MB/s eta 0:00:01
#    ------------------- -------------------- 2.6/5.5 MB 4.3 MB/s eta 0:00:01
#    ------------------- -------------------- 2.7/5.5 MB 4.0 MB/s eta 0:00:01
#    ------------------- -------------------- 2.7/5.5 MB 4.0 MB/s eta 0:00:01
#    ------------------- -------------------- 2.7/5.5 MB 4.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.2/5.5 MB 3.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.3/5.5 MB 3.9 MB/s eta 0:00:01
#    ------------------------- -------------- 3.5/5.5 MB 3.8 MB/s eta 0:00:01
#    -------------------------- ------------- 3.7/5.5 MB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 3.9/5.5 MB 3.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.1/5.5 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 4.2/5.5 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 4.4/5.5 MB 3.8 MB/s eta 0:00:01
#    --------------------------------- ------ 4.6/5.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.8/5.5 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.9/5.5 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 5.1/5.5 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 5.3/5.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 3.8 MB/s eta 0:00:00
# Using cached torch-2.2.1-cp38-cp38-win_amd64.whl (198.6 MB)
# Using cached matplotlib-3.7.5-cp38-cp38-win_amd64.whl (7.5 MB)
# Using cached pillow-10.2.0-cp38-cp38-win_amd64.whl (2.6 MB)
# Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.2/38.6 MB 5.0 MB/s eta 0:00:08
#     --------------------------------------- 0.5/38.6 MB 5.2 MB/s eta 0:00:08
#     --------------------------------------- 0.7/38.6 MB 5.2 MB/s eta 0:00:08
#     --------------------------------------- 0.9/38.6 MB 5.2 MB/s eta 0:00:08
#    - -------------------------------------- 1.1/38.6 MB 4.9 MB/s eta 0:00:08
#    - -------------------------------------- 1.4/38.6 MB 4.8 MB/s eta 0:00:08
#    - -------------------------------------- 1.6/38.6 MB 4.9 MB/s eta 0:00:08
#    - -------------------------------------- 1.8/38.6 MB 4.7 MB/s eta 0:00:08
#    - -------------------------------------- 1.9/38.6 MB 4.7 MB/s eta 0:00:08
MB/s eta 0:00:01
#    ----------- ---------------------------- 1.1/3.8 MB 2.8 MB/s eta 0:00:01
#    ------------ --------------------------- 1.1/3.8 MB 2.9 MB/s eta 0:00:01
#    ------------ --------------------------- 1.2/3.8 MB 2.6 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/3.8 MB 2.6 MB/s eta 0:00:01
#    --------------- ------------------------ 1.4/3.8 MB 2.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.5/3.8 MB 2.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.6/3.8 MB 2.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.6/3.8 MB 2.4 MB/s eta 0:00:01
#    ------------------ --------------------- 1.7/3.8 MB 2.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.9/3.8 MB 2.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.2/3.8 MB 2.5 MB/s eta 0:00:01
#    ------------------------ --------------- 2.3/3.8 MB 2.6 MB/s eta 0:00:01
#    -------------------------- ------------- 2.5/3.8 MB 2.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.8/3.8 MB 2.8 MB/s eta 0:00:01
#    ------------------------------- -------- 3.0/3.8 MB 2.9 MB/s eta 0:00:01
#    --------------------------------- ------ 3.2/3.8 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 3.5/3.8 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 3.6/3.8 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 3.1 MB/s eta 0:00:00
# Using cached importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Using cached kiwisolver-1.4.5-cp38-cp38-win_amd64.whl (56 kB)
# Downloading Markdown-3.5.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.9 kB ? eta -:--:--
#    ---------------------------------------- 103.9/103.9 kB 3.0 MB/s eta 0:00:00
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading protobuf-4.25.3-cp38-cp38-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    ----------- ---------------------------- 122.9/413.4 kB 3.6 MB/s eta 0:00:01
#    -------------------------- ------------- 276.5/413.4 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 413.4/413.4 kB 3.7 MB/s eta 0:00:00
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.7 kB ? eta -:--:--
#    ------------------------- -------------- 143.4/226.7 kB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 226.7/226.7 kB 2.8 MB/s eta 0:00:00
# Using cached wheel-0.42.0-py3-none-any.whl (65 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached fsspec-2024.2.0-py3-none-any.whl (170 kB)
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.3.2-cp38-cp38-win_amd64.whl (99 kB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl (17 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#    ---------------------------------------- 0.0/181.3 kB ? eta -:--:--
#    --------------------------- ------------ 122.9/181.3 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 181.3/181.3 kB 2.7 MB/s eta 0:00:00
# Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#    ---------------------------------------- 151.7/151.7 kB 4.6 MB/s eta 0:00:00
# Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#    ---------------------------------------- 0.0/84.9 kB ? eta -:--:--
#    ---------------------------------------- 84.9/84.9 kB 4.7 MB/s eta 0:00:00
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml): started
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml): finished with status 'done'
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446679 sha256=d5a650afcb80556aef2459933b07e9442113ca813da4f5bb0990ebfbfe0f94e1
#   Stored in directory: c:\users\prash\appdata\local\pip\cache\wheels\84\55\09\367b3a18e3c0cf9c69af93d77818a6ea19493121c65af499f6
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: pytz, mpmath, farama-notifications, wheel, urllib3, tzdata, tensorboard-data-server, sympy, pyparsing, pyasn1, protobuf, pillow, opencv-python, oauthlib, networkx, mdurl, MarkupSafe, kiwisolver, importlib-resources, idna, grpcio, fsspec, fonttools, filelock, cycler, contourpy, click, charset-normalizer, certifi, cachetools, absl-py, werkzeug, rsa, requests, pyasn1-modules, pandas, matplotlib, markdown-it-py, markdown, jinja2, gymnasium, ale-py, torch, shimmy, rich, requests-oauthlib, google-auth, AutoROM.accept-rom-license, autorom, stable-baselines3, google-auth-oauthlib, tensorboard
# Successfully installed AutoROM.accept-rom-license-0.6.1 MarkupSafe-2.1.5 absl-py-2.1.0 ale-py-0.8.1 autorom-0.6.1 cachetools-5.3.2 certifi-2024.2.2 charset-normalizer-3.3.2 click-8.1.7 contourpy-1.1.1 cycler-0.12.1 farama-notifications-0.0.4 filelock-3.13.1 fonttools-4.49.0 fsspec-2024.2.0 google-auth-2.28.1 google-auth-oauthlib-1.0.0 grpcio-1.62.0 gymnasium-0.29.1 idna-3.6 importlib-resources-6.1.1 jinja2-3.1.3 kiwisolver-1.4.5 markdown-3.5.2 markdown-it-py-3.0.0 matplotlib-3.7.5 mdurl-0.1.2 mpmath-1.3.0 networkx-3.1 oauthlib-3.2.2 opencv-python-4.9.0.80 pandas-2.0.3 pillow-10.2.0 protobuf-4.25.3 pyasn1-0.5.1 pyasn1-modules-0.3.0 pyparsing-3.1.1 pytz-2024.1 requests-2.31.0 requests-oauthlib-1.3.1 rich-13.7.0 rsa-4.9 shimmy-1.3.0 stable-baselines3-2.2.1 sympy-1.12 tensorboard-2.14.0 tensorboard-data-server-0.7.2 torch-2.2.1 tzdata-2024.1 urllib3-2.2.1 werkzeug-3.0.1 wheel-0.42.0

# %%
# Import Frame Stacker Wrapper and GrayScaling Wrapper
from gym.wrappers import GrayScaleObservation
# Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
# Import Matplotlib to show the impact of frame stacking
from matplotlib import pyplot as plt

# %%
# 1. Create the base environment
env = gym_super_mario_bros.make('SuperMarioBros-v0')
# 2. Simplify the controls 
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)
# 4. Wrap inside the Dummy Environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last')
# Out:
# d:\Github\Retro-game\env38\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 8
#       6 env = GrayScaleObservation(env, keep_dim=True)
#       7 # 4. Wrap inside the Dummy Environment
# ----> 8 env = DummyVecEnv([lambda: env])
#       9 # 5. Stack the frames
#      10 env = VecFrameStack(env, 4, channels_order='last')
#
# File d:\Github\Retro-game\env38\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:30, in DummyVecEnv.__init__(self, env_fns)
#      29 def __init__(self, env_fns: List[Callable[[], gym.Env]]):
# ---> 30     self.envs = [_patch_env(fn()) for fn in env_fns]
#      31     if len(set([id(env.unwrapped) for env in self.envs])) != len(self.envs):
#      32         raise ValueError(
#      33             "You tried to create multiple environments, but the function to create them returned the same instance "
#      34             "instead of creating different objects. "
#    (...)
#      39             "Please read https://github.com/DLR-RM/stable-baselines3/issues/1151 for more information."
#      40         )
#
# File d:\Github\Retro-game\env38\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:30, in <listcomp>(.0)
#      29 def __init__(self, env_fns: List[Callable[[], gym.Env]]):
# ---> 30     self.envs = [_patch_env(fn()) for fn in env_fns]
#      31     if len(set([id(env.unwrapped) for env in self.envs])) != len(self.envs):
#      32         raise ValueError(
#      33             "You tried to create multiple environments, but the function to create them returned the same instance "
#      34             "instead of creating different objects. "
#    (...)
#      39             "Please read https://github.com/DLR-RM/stable-baselines3/issues/1151 for more information."
#      40         )
#
# File d:\Github\Retro-game\env38\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:58, in _patch_env(env)
#      49 warnings.warn(
#      50     "You provided an OpenAI Gym environment. "
#      51     "We strongly recommend transitioning to Gymnasium environments. "
#      52     "Stable-Baselines3 is automatically wrapping your environments in a compatibility "
#      53     "layer, which could potentially cause issues."
#      54 )
#      56 if "seed" in signature(env.unwrapped.reset).parameters:
#      57     # Gym 0.26+ env
# ---> 58     return shimmy.GymV26CompatibilityV0(env=env)
#      59 # Gym 0.21 env
#      60 return shimmy.GymV21CompatibilityV0(env=env)
#
# File d:\Github\Retro-game\env38\lib\site-packages\shimmy\openai_gym_compatibility.py:84, in GymV26CompatibilityV0.__init__(self, env_id, make_kwargs, env)
#      81 self.action_space = _convert_space(self.gym_env.action_space)
#      83 self.metadata = getattr(self.gym_env, "metadata", {"render_modes": []})
# ---> 84 self.render_mode = self.gym_env.render_mode
#      85 self.reward_range = getattr(self.gym_env, "reward_range", None)
#      86 self.spec = getattr(self.gym_env, "spec", None)
#
# File d:\Github\Retro-game\env38\lib\site-packages\gym\core.py:262, in Wrapper.__getattr__(self, name)
#     260 if name.startswith("_"):
#     261     raise AttributeError(f"accessing private attribute '{name}' is prohibited")
# --> 262 return getattr(self.env, name)
#
# File d:\Github\Retro-game\env38\lib\site-packages\gym\core.py:262, in Wrapper.__getattr__(self, name)
#     260 if name.startswith("_"):
#     261     raise AttributeError(f"accessing private attribute '{name}' is prohibited")
# --> 262 return getattr(self.env, name)
#
#     [... skipping similar frames: Wrapper.__getattr__ at line 262 (2 times)]
#
# File d:\Github\Retro-game\env38\lib\site-packages\gym\core.py:262, in Wrapper.__getattr__(self, name)
#     260 if name.startswith("_"):
#     261     raise AttributeError(f"accessing private attribute '{name}' is prohibited")
# --> 262 return getattr(self.env, name)
#
# AttributeError: 'SuperMarioBrosEnv' object has no attribute 'render_mode'

# %%
state = env.reset()

# %%
state, reward, done, info = env.step([5])

# %%
plt.figure(figsize=(20,16))
for idx in range(state.shape[3]):
    plt.subplot(1,4,idx+1)
    plt.imshow(state[0][:,:,idx])
plt.show()

# %% [markdown]
# # 3. Train the RL Model

# %%
# Import os for file path management
import os 
# Import PPO for algos
from stable_baselines3 import PPO
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
# This is the AI model started
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, 
            n_steps=512)

# %%
# Train the AI model, this is where the AI model starts to learn
model.learn(total_timesteps=1000000, callback=callback)

# %%
model.save('thisisatestmodel')

# %% [markdown]
# # 4. Test it Out

# %%
# Load model
model = PPO.load('./train/best_model_1000000')

# %%
state = env.reset()

# %%
# Start the game 
state = env.reset()
# Loop through the game
while True: 
    
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
